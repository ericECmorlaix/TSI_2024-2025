# %% [markdown]
# ## Prise en main du système
#
# ### Description
#
# #### Le produit industriel
#
# - **Réaliser** une recherche sur le site [Edelkrone](https://edelkrone.com/) afin de compléter la phrase :
#
# > Le rail Edelkrone est un rail professionnel qui permet ...
#
#
# Le rail peut être utilisé de deux façons, soit posé sur une table (Figure 1), soit vissé sur un
# pied photo (Figure 2).
#
# ![image.png](attachment:image.png)
#
# - **Décrire** la grande particularité de mouvement de ce rail en vous appuyant sur un schéma cinématique :
#
# > ...

# %% [markdown]
# #### La maquette dictatisée
#
# La société CREA a équipé ce rail d'un motoréducteur avec codeur incrémental afin de le motoriser et de le dicdactiser pour réaliser des mesures.
#
# Une tête motorisée par un servomoteur et comprenant un pointeur laser et un capteur de distance permet d'ajouter un axe de rotation.
#
# - **Rechercher** sur le site [Edelkrone](https://edelkrone.com/) une illustration qui montre l'intérêt d'un tel dispositif et **l'expliquer**.
#
# > La tête motorisée permet ...
#
# La société CREA a développée une application logicielle qui permet de piloter le système à travers une interface WEB.
#
# - **Proposer** une démarche pour vous connecter à ce site WEB en local (SSID du serveur `CREA-SLIDER-XXXX`, mot de passe `sliderCREA`, IP fixe `192.168.240.1`)
#
# > ...

# %% [markdown]
# ### Mise en oeuvre
#
# Accéder à l'interface WEB.
#
# Déclarer la configuration que vous utilisez encochant les cases correspondantes.
#
# Avant de lancer des mesures sur le rail, vous devrez faire une prise d’origine. Cette opération va mesurer l'amplitude
# du déplacement et positionner le chariot à l'origine.
#
# Réaliser un traveling...
#
# Puis explorer différentes fonctionnalitées...
